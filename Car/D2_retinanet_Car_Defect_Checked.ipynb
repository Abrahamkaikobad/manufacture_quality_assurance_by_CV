# %% [markdown]
# # [How to train Detectron2 with Custom COCO Datasets](https://www.dlology.com/blog/how-to-train-detectron2-with-custom-coco-datasets/) | DLology
#
# <img src="https://dl.fbaipublicfiles.com/detectron2/Detectron2-Logo-Horz.png" width="500">
#
# This notebook will help you get started with this framwork by training a instance segmentation model with your custom COCO datasets.

# %% [markdown]
# # Install detectron2

# %%
# !pip install -U torch torchvision
# !pip install git+https://github.com/facebookresearch/fvcore.git
import torch, torchvision
torch.__version__
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Collecting torch
#   Downloading torch-2.3.0-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.17.1+cu121)
# Collecting torchvision
#   Downloading torchvision-0.18.0-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 95.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.9 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting triton==2.3.0 (from torch)
#   Downloading triton-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 7.0 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 2.2.0
#     Uninstalling triton-2.2.0:
#       Successfully uninstalled triton-2.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1+cu121
#     Uninstalling torch-2.2.1+cu121:
#       Successfully uninstalled torch-2.2.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.17.1+cu121
#     Uninstalling torchvision-0.17.1+cu121:
#       Successfully uninstalled torchvision-0.17.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.2.1+cu121 requires torch==2.2.1, but you have torch 2.3.0 which is incompatible.
# torchtext 0.17.1 requires torch==2.2.1, but you have torch 2.3.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 torch-2.3.0 torchvision-0.18.0 triton-2.3.0
# Collecting git+https://github.com/facebookresearch/fvcore.git
#   Cloning https://github.com/facebookresearch/fvcore.git to /tmp/pip-req-build-a126n9c4
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/fvcore.git /tmp/pip-req-build-a126n9c4
#   Resolved https://github.com/facebookresearch/fvcore.git to commit 1856b63f7067a987470999876d7d38ee241a6a32
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore==0.1.6) (1.25.2)
# Collecting yacs>=0.1.6 (from fvcore==0.1.6)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore==0.1.6) (6.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fvcore==0.1.6) (4.66.2)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore==0.1.6) (2.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from fvcore==0.1.6) (9.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore==0.1.6) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore==0.1.6)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from iopath>=0.1.7->fvcore==0.1.6) (4.11.0)
# Collecting portalocker (from iopath>=0.1.7->fvcore==0.1.6)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.6-py3-none-any.whl size=65529 sha256=7b01364f42c38ce47d02786fc5491fda069de4fcc4af4f5f848acf8340d92a8b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ibooprwq/wheels/8f/cb/6a/3b7ac0e01781855ca3d1417ebf9e15e20d5b7fe37ab063aa50
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31532 sha256=57adaad4cb7e6307e137f081dcddbde3c7e4b6cb37b680224b43ee6e8fe14835
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built fvcore iopath
# Installing collected packages: yacs, portalocker, iopath, fvcore
# Successfully installed fvcore-0.1.6 iopath-0.1.10 portalocker-2.8.2 yacs-0.1.8
# '2.3.0+cu121'

# %%
# !git clone https://github.com/facebookresearch/detectron2 detectron2_repo
# !pip install -e detectron2_repo
# Out:
# fatal: destination path 'detectron2_repo' already exists and is not an empty directory.
# Obtaining file:///content/detectron2_repo
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.7)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.4.0)
# Requirement already satisfied: yacs>=0.1.8 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.66.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.15.2)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (1.3.2)
# Requirement already satisfied: black in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (24.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (24.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.25.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.2.1)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.11.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.63.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Installing collected packages: detectron2
#   Attempting uninstall: detectron2
#     Found existing installation: detectron2 0.6
#     Uninstalling detectron2-0.6:
#       Successfully uninstalled detectron2-0.6
#   Running setup.py develop for detectron2
# Successfully installed detectron2-0.6

# %%
# You may need to restart your runtime prior to this, to let your installation take effect
# Some basic setup
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import matplotlib.pyplot as plt
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %% [markdown]
# # Train on Cars Defect Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Defectron2/Car_Defect_Defectron/train/_annotations.coco.json
# Out:
# [Errno 20] Not a directory: '/content/drive/MyDrive/Defectron2/Car_Defect_Defectron/train/_annotations.coco.json'
# /content

# %%
import os

directory = "/content/drive/MyDrive/Defectron2/Car_Defect_Defectron/train/"
target_file = "_annotations.coco.json"

# List all files in the directory
files = os.listdir(directory)

# Filter the list to find the target file
target_files = [file for file in files if file == target_file]

# Check if the target file exists
if target_files:
    print(f"Found '{target_file}' file in the directory.")  # Corrected the print statement
    # If you want to get the full path of the file, you can use os.path.join()
    full_path = os.path.join(directory, target_files[0])
    print("Full path:", full_path)
else:
    print("File not found in the directory.")
# Out:
# Found '_annotations.coco.json' file in the directory.
# Full path: /content/drive/MyDrive/Defectron2/Car_Defect_Defectron/train/_annotations.coco.json

# %%
from detectron2.data.datasets import register_coco_instances
register_coco_instances("Car_defect", {}, "/content/drive/MyDrive/Defectron2/Car_Defect_Defectron/train/_annotations.coco.json", "/content/drive/MyDrive/Defectron2/Car_Defect_Defectron/train/")

# %%
Car_defect_metadata = MetadataCatalog.get("Car_defect")
dataset_dicts = DatasetCatalog.get("Car_defect")
# Out:
# WARNING [05/06 15:07:57 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [05/06 15:07:57 d2.data.datasets.coco]: Loaded 2626 images in COCO format from /content/drive/MyDrive/Defectron2/Car_Defect_Defectron/train/_annotations.coco.json

# %%
import random
for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=Car_defect_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=320x320>
# <PIL.Image.Image image mode=RGB size=320x320>
# <PIL.Image.Image image mode=RGB size=320x320>

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2 import model_zoo

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/retinanet_R_101_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("Car_defect",)
cfg.DATASETS.TEST = ()
cfg.DATALOADER.NUM_WORKERS = 0
cfg.MODEL.WEIGHTS = "detectron2://ImageNetPretrained/MSRA/R-101.pkl"  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00025  # pick a good LR
cfg.SOLVER.MAX_ITER = 3000    # 300 iterations seems good enough for this toy dataset; you may need to train longer for a practical dataset
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 256   # faster, and good enough for this toy dataset (default: 512)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 4

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# WARNING:fvcore.common.config:Loading config /content/detectron2_repo/detectron2/model_zoo/configs/COCO-Detection/../Base-RetinaNet.yaml with yaml.unsafe_load. Your machine may be at risk if the file contains malicious content.
# [05/06 15:39:31 d2.engine.defaults]: Model:
# RetinaNet(
#   (backbone): FPN(
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelP6P7(
#       (p6): Conv2d(2048, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (p7): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (head): RetinaNetHead(
#     (cls_subnet): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU()
#       (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): ReLU()
#       (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#     )
#     (bbox_subnet): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU()
#       (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): ReLU()
#       (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#     )
#     (cls_score): Conv2d(256, 720, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bbox_pred): Conv2d(256, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (anchor_generator): DefaultAnchorGenerator(
#     (cell_anchors): BufferList()
#   )
# )
# WARNING [05/06 15:39:31 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [05/06 15:39:31 d2.data.datasets.coco]: Loaded 2626 images in COCO format from /content/drive/MyDrive/Defectron2/Car_Defect_Defectron/train/_annotations.coco.json
# [05/06 15:39:31 d2.data.build]: Removed 0 images with no usable annotations. 2626 images left.
# [05/06 15:39:32 d2.data.build]: Distribution of instances among all 5 categories:
# |   category    | #instances   |  category  | #instances   |  category  | #instances   |
# |:-------------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# | Car-defect-.. | 0            |  Accident  | 266          |    Dent    | 1363         |
# |  Glass-Break  | 394          |  Scratch   | 1472         |            |              |
# |     total     | 3495         |            |              |            |              |
# [05/06 15:39:32 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [05/06 15:39:32 d2.data.build]: Using training sampler TrainingSampler
# [05/06 15:39:32 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [05/06 15:39:32 d2.data.common]: Serializing 2626 elements to byte tensors and concatenating them all ...
# [05/06 15:39:32 d2.data.common]: Serialized dataset takes 0.83 MiB
# [05/06 15:39:32 d2.data.build]: Making batched data loader with batch_size=2
# WARNING [05/06 15:39:32 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [05/06 15:39:32 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from detectron2://ImageNetPretrained/MSRA/R-101.pkl ...
# R-101.pkl: 179MB [00:01, 116MB/s]
# [05/06 15:39:33 d2.checkpoint.c2_model_loading]: Renaming Caffe2 weights ......
# [05/06 15:39:34 d2.checkpoint.c2_model_loading]: Following weights matched with submodule backbone.bottom_up - Total num: 105
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# backbone.fpn_lateral3.{bias, weight}
# backbone.fpn_lateral4.{bias, weight}
# backbone.fpn_lateral5.{bias, weight}
# backbone.fpn_output3.{bias, weight}
# backbone.fpn_output4.{bias, weight}
# backbone.fpn_output5.{bias, weight}
# backbone.top_block.p6.{bias, weight}
# backbone.top_block.p7.{bias, weight}
# head.bbox_pred.{bias, weight}
# head.bbox_subnet.0.{bias, weight}
# head.bbox_subnet.2.{bias, weight}
# head.bbox_subnet.4.{bias, weight}
# head.bbox_subnet.6.{bias, weight}
# head.cls_score.{bias, weight}
# head.cls_subnet.0.{bias, weight}
# head.cls_subnet.2.{bias, weight}
# head.cls_subnet.4.{bias, weight}
# head.cls_subnet.6.{bias, weight}
# WARNING:fvcore.common.checkpoint:The checkpoint state_dict contains keys that are not used by the model:
#   fc1000.{bias, weight}
# [05/06 15:39:34 d2.engine.train_loop]: Starting training from iteration 0
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [05/06 15:40:09 d2.utils.events]:  eta: 1:13:44  iter: 19  total_loss: 1.667  loss_cls: 1.088  loss_box_reg: 0.5685    time: 1.6199  last_time: 1.3016  data_time: 1.0441  last_data_time: 0.9802   lr: 4.9953e-06  max_mem: 3104M
# [05/06 15:40:44 d2.utils.events]:  eta: 1:12:35  iter: 39  total_loss: 1.927  loss_cls: 1.257  loss_box_reg: 0.6522    time: 1.5413  last_time: 1.4814  data_time: 1.0046  last_data_time: 0.9565   lr: 9.9902e-06  max_mem: 3104M
# [05/06 15:41:14 d2.utils.events]:  eta: 1:12:09  iter: 59  total_loss: 1.702  loss_cls: 1.148  loss_box_reg: 0.5808    time: 1.5157  last_time: 1.5383  data_time: 1.0107  last_data_time: 1.0110   lr: 1.4985e-05  max_mem: 3104M
# [05/06 15:41:43 d2.utils.events]:  eta: 1:11:45  iter: 79  total_loss: 1.897  loss_cls: 1.218  loss_box_reg: 0.6727    time: 1.5066  last_time: 1.5812  data_time: 1.0069  last_data_time: 1.1051   lr: 1.998e-05  max_mem: 3104M
# [05/06 15:42:14 d2.utils.events]:  eta: 1:11:39  iter: 99  total_loss: 1.766  loss_cls: 1.173  loss_box_reg: 0.5967    time: 1.5095  last_time: 1.4430  data_time: 1.0277  last_data_time: 1.0224   lr: 2.4975e-05  max_mem: 3104M
# [05/06 15:42:43 d2.utils.events]:  eta: 1:11:03  iter: 119  total_loss: 1.737  loss_cls: 1.165  loss_box_reg: 0.5717    time: 1.5046  last_time: 1.3987  data_time: 1.0020  last_data_time: 1.0035   lr: 2.997e-05  max_mem: 3104M
# [05/06 15:43:13 d2.utils.events]:  eta: 1:10:32  iter: 139  total_loss: 1.888  loss_cls: 1.245  loss_box_reg: 0.6454    time: 1.5000  last_time: 1.4187  data_time: 0.9974  last_data_time: 0.9673   lr: 3.4965e-05  max_mem: 3104M
# [05/06 15:43:43 d2.utils.events]:  eta: 1:10:09  iter: 159  total_loss: 1.84  loss_cls: 1.221  loss_box_reg: 0.6258    time: 1.4999  last_time: 1.4540  data_time: 1.0264  last_data_time: 1.0334   lr: 3.996e-05  max_mem: 3104M
# [05/06 15:44:12 d2.utils.events]:  eta: 1:09:44  iter: 179  total_loss: 1.714  loss_cls: 1.151  loss_box_reg: 0.5556    time: 1.4985  last_time: 1.6314  data_time: 1.0065  last_data_time: 1.0856   lr: 4.4955e-05  max_mem: 3104M
# [05/06 15:44:42 d2.utils.events]:  eta: 1:09:06  iter: 199  total_loss: 2.03  loss_cls: 1.368  loss_box_reg: 0.6625    time: 1.4961  last_time: 1.4656  data_time: 1.0038  last_data_time: 0.9172   lr: 4.995e-05  max_mem: 3104M
# [05/06 15:45:11 d2.utils.events]:  eta: 1:08:40  iter: 219  total_loss: 1.622  loss_cls: 1.068  loss_box_reg: 0.5537    time: 1.4934  last_time: 1.6375  data_time: 0.9998  last_data_time: 1.0838   lr: 5.4945e-05  max_mem: 3104M
# [05/06 15:45:41 d2.utils.events]:  eta: 1:08:10  iter: 239  total_loss: 1.863  loss_cls: 1.226  loss_box_reg: 0.6185    time: 1.4933  last_time: 1.3345  data_time: 1.0198  last_data_time: 0.8611   lr: 5.994e-05  max_mem: 3104M
# [05/06 15:46:11 d2.utils.events]:  eta: 1:07:37  iter: 259  total_loss: 1.893  loss_cls: 1.25  loss_box_reg: 0.6337    time: 1.4911  last_time: 1.4278  data_time: 0.9733  last_data_time: 0.9762   lr: 6.4935e-05  max_mem: 3104M
# [05/06 15:46:40 d2.utils.events]:  eta: 1:07:07  iter: 279  total_loss: 1.78  loss_cls: 1.166  loss_box_reg: 0.6231    time: 1.4886  last_time: 1.3275  data_time: 1.0003  last_data_time: 0.9327   lr: 6.993e-05  max_mem: 3104M
# [05/06 15:47:09 d2.utils.events]:  eta: 1:06:41  iter: 299  total_loss: 1.882  loss_cls: 1.227  loss_box_reg: 0.6546    time: 1.4879  last_time: 1.5873  data_time: 1.0336  last_data_time: 1.0390   lr: 7.4925e-05  max_mem: 3104M
# [05/06 15:47:39 d2.utils.events]:  eta: 1:06:16  iter: 319  total_loss: 1.956  loss_cls: 1.285  loss_box_reg: 0.6706    time: 1.4886  last_time: 1.5248  data_time: 1.0272  last_data_time: 1.0535   lr: 7.992e-05  max_mem: 3104M
# [05/06 15:48:09 d2.utils.events]:  eta: 1:05:42  iter: 339  total_loss: 2.014  loss_cls: 1.337  loss_box_reg: 0.6804    time: 1.4876  last_time: 1.3715  data_time: 0.9951  last_data_time: 0.9776   lr: 8.4915e-05  max_mem: 3104M
# [05/06 15:48:39 d2.utils.events]:  eta: 1:05:17  iter: 359  total_loss: 1.682  loss_cls: 1.126  loss_box_reg: 0.562    time: 1.4895  last_time: 1.3760  data_time: 1.0415  last_data_time: 1.0327   lr: 8.991e-05  max_mem: 3104M
# [05/06 15:49:09 d2.utils.events]:  eta: 1:04:47  iter: 379  total_loss: 1.726  loss_cls: 1.125  loss_box_reg: 0.5974    time: 1.4897  last_time: 1.4829  data_time: 1.0269  last_data_time: 1.0320   lr: 9.4905e-05  max_mem: 3104M
# [05/06 15:49:39 d2.utils.events]:  eta: 1:04:18  iter: 399  total_loss: 1.86  loss_cls: 1.222  loss_box_reg: 0.6338    time: 1.4904  last_time: 1.5252  data_time: 1.0059  last_data_time: 1.0751   lr: 9.99e-05  max_mem: 3104M
# [05/06 15:50:09 d2.utils.events]:  eta: 1:03:49  iter: 419  total_loss: 1.822  loss_cls: 1.215  loss_box_reg: 0.5998    time: 1.4910  last_time: 1.5674  data_time: 1.0195  last_data_time: 1.0153   lr: 0.0001049  max_mem: 3104M
# [05/06 15:50:39 d2.utils.events]:  eta: 1:03:18  iter: 439  total_loss: 1.705  loss_cls: 1.14  loss_box_reg: 0.5679    time: 1.4903  last_time: 1.3686  data_time: 0.9987  last_data_time: 0.9507   lr: 0.00010989  max_mem: 3104M
# [05/06 15:51:07 d2.utils.events]:  eta: 1:02:44  iter: 459  total_loss: 1.824  loss_cls: 1.24  loss_box_reg: 0.5972    time: 1.4881  last_time: 1.4127  data_time: 0.9700  last_data_time: 0.9599   lr: 0.00011489  max_mem: 3104M
# [05/06 15:51:42 d2.utils.events]:  eta: 1:02:13  iter: 479  total_loss: 1.646  loss_cls: 1.086  loss_box_reg: 0.5371    time: 1.4982  last_time: 6.2792  data_time: 1.2604  last_data_time: 5.7291   lr: 0.00011988  max_mem: 3104M
# [05/06 15:52:12 d2.utils.events]:  eta: 1:01:44  iter: 499  total_loss: 1.586  loss_cls: 1.081  loss_box_reg: 0.5321    time: 1.4975  last_time: 1.3613  data_time: 1.0148  last_data_time: 0.9609   lr: 0.00012488  max_mem: 3104M
# [05/06 15:52:42 d2.utils.events]:  eta: 1:01:17  iter: 519  total_loss: 2.063  loss_cls: 1.344  loss_box_reg: 0.6874    time: 1.4978  last_time: 1.4698  data_time: 1.0065  last_data_time: 0.9229   lr: 0.00012987  max_mem: 3104M
# [05/06 15:53:12 d2.utils.events]:  eta: 1:00:50  iter: 539  total_loss: 1.681  loss_cls: 1.129  loss_box_reg: 0.5501    time: 1.4986  last_time: 1.3728  data_time: 1.0286  last_data_time: 0.9055   lr: 0.00013487  max_mem: 3104M
# [05/06 15:53:42 d2.utils.events]:  eta: 1:00:20  iter: 559  total_loss: 1.918  loss_cls: 1.301  loss_box_reg: 0.617    time: 1.4986  last_time: 1.4268  data_time: 1.0092  last_data_time: 0.8762   lr: 0.00013986  max_mem: 3104M
# [05/06 15:54:12 d2.utils.events]:  eta: 0:59:51  iter: 579  total_loss: 1.76  loss_cls: 1.172  loss_box_reg: 0.5862    time: 1.4980  last_time: 1.3302  data_time: 1.0044  last_data_time: 0.9776   lr: 0.00014486  max_mem: 3104M
# [05/06 15:54:43 d2.utils.events]:  eta: 0:59:22  iter: 599  total_loss: 1.829  loss_cls: 1.251  loss_box_reg: 0.5822    time: 1.5003  last_time: 1.4653  data_time: 1.0774  last_data_time: 1.0134   lr: 0.00014985  max_mem: 3104M
# [05/06 15:55:12 d2.utils.events]:  eta: 0:58:51  iter: 619  total_loss: 1.983  loss_cls: 1.33  loss_box_reg: 0.6572    time: 1.4988  last_time: 1.5740  data_time: 1.0076  last_data_time: 1.1038   lr: 0.00015485  max_mem: 3104M
# [05/06 15:55:42 d2.utils.events]:  eta: 0:58:20  iter: 639  total_loss: 1.704  loss_cls: 1.149  loss_box_reg: 0.5561    time: 1.4982  last_time: 1.2953  data_time: 0.9985  last_data_time: 0.8460   lr: 0.00015984  max_mem: 3104M
# [05/06 15:56:12 d2.utils.events]:  eta: 0:57:52  iter: 659  total_loss: 1.625  loss_cls: 1.093  loss_box_reg: 0.5334    time: 1.4983  last_time: 1.4261  data_time: 1.0278  last_data_time: 0.9584   lr: 0.00016484  max_mem: 3104M
# [05/06 15:56:42 d2.utils.events]:  eta: 0:57:20  iter: 679  total_loss: 1.813  loss_cls: 1.265  loss_box_reg: 0.5839    time: 1.4978  last_time: 1.4480  data_time: 0.9978  last_data_time: 1.0258   lr: 0.00016983  max_mem: 3104M
# [05/06 15:57:12 d2.utils.events]:  eta: 0:56:51  iter: 699  total_loss: 1.748  loss_cls: 1.197  loss_box_reg: 0.5637    time: 1.4978  last_time: 1.6651  data_time: 1.0015  last_data_time: 1.1197   lr: 0.00017483  max_mem: 3104M
# [05/06 15:57:41 d2.utils.events]:  eta: 0:56:22  iter: 719  total_loss: 1.853  loss_cls: 1.242  loss_box_reg: 0.5833    time: 1.4977  last_time: 1.5166  data_time: 1.0033  last_data_time: 1.0954   lr: 0.00017982  max_mem: 3104M
# [05/06 15:58:11 d2.utils.events]:  eta: 0:55:53  iter: 739  total_loss: 1.873  loss_cls: 1.294  loss_box_reg: 0.574    time: 1.4972  last_time: 1.3746  data_time: 1.0031  last_data_time: 0.9795   lr: 0.00018482  max_mem: 3104M
# [05/06 15:58:41 d2.utils.events]:  eta: 0:55:23  iter: 759  total_loss: 1.714  loss_cls: 1.179  loss_box_reg: 0.5658    time: 1.4970  last_time: 1.5156  data_time: 1.0246  last_data_time: 0.9656   lr: 0.00018981  max_mem: 3104M
# [05/06 15:59:10 d2.utils.events]:  eta: 0:54:54  iter: 779  total_loss: 1.67  loss_cls: 1.119  loss_box_reg: 0.5407    time: 1.4962  last_time: 1.5479  data_time: 0.9960  last_data_time: 1.0970   lr: 0.00019481  max_mem: 3104M
# [05/06 15:59:40 d2.utils.events]:  eta: 0:54:22  iter: 799  total_loss: 1.798  loss_cls: 1.236  loss_box_reg: 0.5684    time: 1.4958  last_time: 1.4203  data_time: 1.0100  last_data_time: 0.9563   lr: 0.0001998  max_mem: 3104M
# [05/06 16:00:09 d2.utils.events]:  eta: 0:53:52  iter: 819  total_loss: 1.826  loss_cls: 1.247  loss_box_reg: 0.5819    time: 1.4949  last_time: 1.4623  data_time: 0.9984  last_data_time: 1.0121   lr: 0.0002048  max_mem: 3104M
# [05/06 16:00:39 d2.utils.events]:  eta: 0:53:24  iter: 839  total_loss: 1.748  loss_cls: 1.187  loss_box_reg: 0.5641    time: 1.4950  last_time: 1.5017  data_time: 1.0349  last_data_time: 1.0296   lr: 0.00020979  max_mem: 3104M
# [05/06 16:01:09 d2.utils.events]:  eta: 0:52:55  iter: 859  total_loss: 1.631  loss_cls: 1.135  loss_box_reg: 0.5068    time: 1.4951  last_time: 1.4447  data_time: 1.0074  last_data_time: 0.8956   lr: 0.00021479  max_mem: 3104M
# [05/06 16:01:39 d2.utils.events]:  eta: 0:52:26  iter: 879  total_loss: 1.755  loss_cls: 1.237  loss_box_reg: 0.5427    time: 1.4954  last_time: 1.5466  data_time: 1.0419  last_data_time: 0.9961   lr: 0.00021978  max_mem: 3104M
# [05/06 16:02:10 d2.utils.events]:  eta: 0:51:57  iter: 899  total_loss: 1.754  loss_cls: 1.189  loss_box_reg: 0.5549    time: 1.4964  last_time: 1.6182  data_time: 1.0320  last_data_time: 1.0661   lr: 0.00022478  max_mem: 3104M
# [05/06 16:02:40 d2.utils.events]:  eta: 0:51:28  iter: 919  total_loss: 1.654  loss_cls: 1.131  loss_box_reg: 0.5218    time: 1.4966  last_time: 1.4204  data_time: 1.0230  last_data_time: 1.0047   lr: 0.00022977  max_mem: 3104M
# [05/06 16:03:09 d2.utils.events]:  eta: 0:50:58  iter: 939  total_loss: 1.744  loss_cls: 1.144  loss_box_reg: 0.6038    time: 1.4959  last_time: 1.2772  data_time: 1.0094  last_data_time: 0.9347   lr: 0.00023477  max_mem: 3104M
# [05/06 16:03:40 d2.utils.events]:  eta: 0:50:28  iter: 959  total_loss: 1.567  loss_cls: 1.044  loss_box_reg: 0.4981    time: 1.4962  last_time: 1.4277  data_time: 1.0213  last_data_time: 0.9736   lr: 0.00023976  max_mem: 3104M
# [05/06 16:04:09 d2.utils.events]:  eta: 0:49:59  iter: 979  total_loss: 1.518  loss_cls: 0.9613  loss_box_reg: 0.559    time: 1.4959  last_time: 1.4571  data_time: 1.0011  last_data_time: 0.9850   lr: 0.00024476  max_mem: 3104M
# [05/06 16:04:40 d2.utils.events]:  eta: 0:49:29  iter: 999  total_loss: 1.474  loss_cls: 0.9059  loss_box_reg: 0.5774    time: 1.4969  last_time: 1.4850  data_time: 1.0721  last_data_time: 1.0198   lr: 0.00024975  max_mem: 3104M
# [05/06 16:05:10 d2.utils.events]:  eta: 0:49:00  iter: 1019  total_loss: 1.565  loss_cls: 1.006  loss_box_reg: 0.5369    time: 1.4968  last_time: 1.5804  data_time: 1.0191  last_data_time: 1.1161   lr: 0.00025  max_mem: 3104M
# [05/06 16:05:40 d2.utils.events]:  eta: 0:48:31  iter: 1039  total_loss: 1.511  loss_cls: 0.9086  loss_box_reg: 0.6102    time: 1.4966  last_time: 1.4499  data_time: 1.0108  last_data_time: 0.9761   lr: 0.00025  max_mem: 3104M
# [05/06 16:06:09 d2.utils.events]:  eta: 0:48:03  iter: 1059  total_loss: 1.375  loss_cls: 0.8218  loss_box_reg: 0.5244    time: 1.4960  last_time: 1.3583  data_time: 0.9911  last_data_time: 0.9584   lr: 0.00025  max_mem: 3104M
# [05/06 16:06:39 d2.utils.events]:  eta: 0:47:35  iter: 1079  total_loss: 1.152  loss_cls: 0.7074  loss_box_reg: 0.4813    time: 1.4959  last_time: 1.3045  data_time: 1.0176  last_data_time: 0.9590   lr: 0.00025  max_mem: 3104M
# [05/06 16:07:09 d2.utils.events]:  eta: 0:47:02  iter: 1099  total_loss: 1.368  loss_cls: 0.7481  loss_box_reg: 0.6066    time: 1.4958  last_time: 1.4456  data_time: 1.0075  last_data_time: 1.0240   lr: 0.00025  max_mem: 3104M
# [05/06 16:07:41 d2.utils.events]:  eta: 0:46:37  iter: 1119  total_loss: 1.329  loss_cls: 0.8269  loss_box_reg: 0.4751    time: 1.4983  last_time: 1.7294  data_time: 1.1611  last_data_time: 1.1815   lr: 0.00025  max_mem: 3104M
# [05/06 16:08:19 d2.utils.events]:  eta: 0:46:09  iter: 1139  total_loss: 1.214  loss_cls: 0.7269  loss_box_reg: 0.4892    time: 1.5046  last_time: 1.4625  data_time: 1.3775  last_data_time: 1.0135   lr: 0.00025  max_mem: 3104M
# [05/06 16:08:49 d2.utils.events]:  eta: 0:45:39  iter: 1159  total_loss: 1.224  loss_cls: 0.7442  loss_box_reg: 0.479    time: 1.5046  last_time: 1.6176  data_time: 1.0155  last_data_time: 1.0611   lr: 0.00025  max_mem: 3104M
# [05/06 16:09:18 d2.utils.events]:  eta: 0:45:05  iter: 1179  total_loss: 1.233  loss_cls: 0.7126  loss_box_reg: 0.5157    time: 1.5039  last_time: 1.5701  data_time: 0.9994  last_data_time: 1.1183   lr: 0.00025  max_mem: 3104M
# [05/06 16:09:48 d2.utils.events]:  eta: 0:44:39  iter: 1199  total_loss: 1.098  loss_cls: 0.6145  loss_box_reg: 0.4733    time: 1.5038  last_time: 1.6339  data_time: 1.0137  last_data_time: 1.0830   lr: 0.00025  max_mem: 3104M
# [05/06 16:10:22 d2.utils.events]:  eta: 0:44:11  iter: 1219  total_loss: 1.324  loss_cls: 0.7705  loss_box_reg: 0.5003    time: 1.5067  last_time: 1.5725  data_time: 1.1628  last_data_time: 1.0200   lr: 0.00025  max_mem: 3104M
# [05/06 16:10:52 d2.utils.events]:  eta: 0:43:43  iter: 1239  total_loss: 1.043  loss_cls: 0.6148  loss_box_reg: 0.477    time: 1.5068  last_time: 1.5659  data_time: 1.0422  last_data_time: 1.1153   lr: 0.00025  max_mem: 3104M
# [05/06 16:11:23 d2.utils.events]:  eta: 0:43:15  iter: 1259  total_loss: 1.156  loss_cls: 0.6565  loss_box_reg: 0.5119    time: 1.5074  last_time: 1.3961  data_time: 1.0595  last_data_time: 0.9994   lr: 0.00025  max_mem: 3104M
# [05/06 16:11:52 d2.utils.events]:  eta: 0:42:44  iter: 1279  total_loss: 1.222  loss_cls: 0.648  loss_box_reg: 0.5252    time: 1.5066  last_time: 1.5053  data_time: 0.9857  last_data_time: 0.9542   lr: 0.00025  max_mem: 3104M
# [05/06 16:12:22 d2.utils.events]:  eta: 0:42:14  iter: 1299  total_loss: 1.197  loss_cls: 0.6816  loss_box_reg: 0.5268    time: 1.5065  last_time: 1.5489  data_time: 1.0116  last_data_time: 1.0945   lr: 0.00025  max_mem: 3104M
# [05/06 16:12:45 d2.utils.events]:  eta: 0:41:44  iter: 1319  total_loss: 1.271  loss_cls: 0.777  loss_box_reg: 0.4954    time: 1.5014  last_time: 0.6205  data_time: 0.6950  last_data_time: 0.0625   lr: 0.00025  max_mem: 3104M
# [05/06 16:12:56 d2.utils.events]:  eta: 0:41:12  iter: 1339  total_loss: 1.181  loss_cls: 0.7173  loss_box_reg: 0.4874    time: 1.4868  last_time: 0.5284  data_time: 0.0517  last_data_time: 0.0500   lr: 0.00025  max_mem: 3104M
# [05/06 16:13:07 d2.utils.events]:  eta: 0:40:35  iter: 1359  total_loss: 1.087  loss_cls: 0.6331  loss_box_reg: 0.4825    time: 1.4729  last_time: 0.5000  data_time: 0.0549  last_data_time: 0.0401   lr: 0.00025  max_mem: 3104M
# [05/06 16:13:17 d2.utils.events]:  eta: 0:40:01  iter: 1379  total_loss: 1.015  loss_cls: 0.5907  loss_box_reg: 0.4294    time: 1.4593  last_time: 0.5291  data_time: 0.0514  last_data_time: 0.0485   lr: 0.00025  max_mem: 3104M
# [05/06 16:13:28 d2.utils.events]:  eta: 0:39:25  iter: 1399  total_loss: 1.141  loss_cls: 0.6285  loss_box_reg: 0.4801    time: 1.4458  last_time: 0.4798  data_time: 0.0538  last_data_time: 0.0452   lr: 0.00025  max_mem: 3104M
# [05/06 16:13:38 d2.utils.events]:  eta: 0:38:50  iter: 1419  total_loss: 1.047  loss_cls: 0.6117  loss_box_reg: 0.4325    time: 1.4328  last_time: 0.6175  data_time: 0.0497  last_data_time: 0.0710   lr: 0.00025  max_mem: 3104M
# [05/06 16:13:49 d2.utils.events]:  eta: 0:38:18  iter: 1439  total_loss: 1.155  loss_cls: 0.6639  loss_box_reg: 0.5224    time: 1.4201  last_time: 0.5937  data_time: 0.0506  last_data_time: 0.0498   lr: 0.00025  max_mem: 3104M
# [05/06 16:14:00 d2.utils.events]:  eta: 0:37:46  iter: 1459  total_loss: 1.226  loss_cls: 0.7244  loss_box_reg: 0.4969    time: 1.4081  last_time: 0.5951  data_time: 0.0512  last_data_time: 0.0467   lr: 0.00025  max_mem: 3104M
# [05/06 16:14:11 d2.utils.events]:  eta: 0:37:13  iter: 1479  total_loss: 1.169  loss_cls: 0.7279  loss_box_reg: 0.4673    time: 1.3965  last_time: 0.5233  data_time: 0.0528  last_data_time: 0.0471   lr: 0.00025  max_mem: 3104M
# [05/06 16:14:22 d2.utils.events]:  eta: 0:36:38  iter: 1499  total_loss: 1.207  loss_cls: 0.7103  loss_box_reg: 0.5196    time: 1.3851  last_time: 0.6067  data_time: 0.0562  last_data_time: 0.0482   lr: 0.00025  max_mem: 3104M
# [05/06 16:14:32 d2.utils.events]:  eta: 0:36:02  iter: 1519  total_loss: 1.155  loss_cls: 0.6845  loss_box_reg: 0.465    time: 1.3739  last_time: 0.6372  data_time: 0.0504  last_data_time: 0.0814   lr: 0.00025  max_mem: 3104M
# [05/06 16:14:43 d2.utils.events]:  eta: 0:35:23  iter: 1539  total_loss: 0.9914  loss_cls: 0.5955  loss_box_reg: 0.4208    time: 1.3633  last_time: 0.6014  data_time: 0.0522  last_data_time: 0.0491   lr: 0.00025  max_mem: 3104M
# [05/06 16:14:54 d2.utils.events]:  eta: 0:34:47  iter: 1559  total_loss: 1.151  loss_cls: 0.6256  loss_box_reg: 0.5201    time: 1.3525  last_time: 0.5999  data_time: 0.0538  last_data_time: 0.0481   lr: 0.00025  max_mem: 3104M
# [05/06 16:15:04 d2.utils.events]:  eta: 0:34:09  iter: 1579  total_loss: 1.133  loss_cls: 0.6279  loss_box_reg: 0.4881    time: 1.3420  last_time: 0.4888  data_time: 0.0543  last_data_time: 0.0387   lr: 0.00025  max_mem: 3104M
# [05/06 16:15:15 d2.utils.events]:  eta: 0:33:31  iter: 1599  total_loss: 1.028  loss_cls: 0.5664  loss_box_reg: 0.4848    time: 1.3316  last_time: 0.4884  data_time: 0.0518  last_data_time: 0.0380   lr: 0.00025  max_mem: 3104M
# [05/06 16:15:25 d2.utils.events]:  eta: 0:32:57  iter: 1619  total_loss: 1.01  loss_cls: 0.5976  loss_box_reg: 0.459    time: 1.3214  last_time: 0.4622  data_time: 0.0487  last_data_time: 0.0598   lr: 0.00025  max_mem: 3104M
# [05/06 16:15:35 d2.utils.events]:  eta: 0:32:20  iter: 1639  total_loss: 0.979  loss_cls: 0.5418  loss_box_reg: 0.4684    time: 1.3116  last_time: 0.4971  data_time: 0.0486  last_data_time: 0.0382   lr: 0.00025  max_mem: 3104M
# [05/06 16:15:45 d2.utils.events]:  eta: 0:31:43  iter: 1659  total_loss: 1.021  loss_cls: 0.5556  loss_box_reg: 0.4607    time: 1.3019  last_time: 0.5033  data_time: 0.0489  last_data_time: 0.0458   lr: 0.00025  max_mem: 3104M
# [05/06 16:15:56 d2.utils.events]:  eta: 0:31:07  iter: 1679  total_loss: 1.002  loss_cls: 0.5561  loss_box_reg: 0.455    time: 1.2928  last_time: 0.5183  data_time: 0.0566  last_data_time: 0.0463   lr: 0.00025  max_mem: 3104M
# [05/06 16:16:07 d2.utils.events]:  eta: 0:30:24  iter: 1699  total_loss: 0.9711  loss_cls: 0.5483  loss_box_reg: 0.3876    time: 1.2839  last_time: 0.5289  data_time: 0.0546  last_data_time: 0.0522   lr: 0.00025  max_mem: 3104M
# [05/06 16:16:17 d2.utils.events]:  eta: 0:29:43  iter: 1719  total_loss: 0.9915  loss_cls: 0.546  loss_box_reg: 0.436    time: 1.2749  last_time: 0.5382  data_time: 0.0505  last_data_time: 0.0890   lr: 0.00025  max_mem: 3104M
# [05/06 16:16:28 d2.utils.events]:  eta: 0:28:59  iter: 1739  total_loss: 1.073  loss_cls: 0.5924  loss_box_reg: 0.4896    time: 1.2665  last_time: 0.5118  data_time: 0.0522  last_data_time: 0.0401   lr: 0.00025  max_mem: 3104M
# [05/06 16:16:39 d2.utils.events]:  eta: 0:28:13  iter: 1759  total_loss: 0.9476  loss_cls: 0.5523  loss_box_reg: 0.4223    time: 1.2582  last_time: 0.5926  data_time: 0.0560  last_data_time: 0.0453   lr: 0.00025  max_mem: 3104M
# [05/06 16:16:49 d2.utils.events]:  eta: 0:27:04  iter: 1779  total_loss: 0.936  loss_cls: 0.5258  loss_box_reg: 0.4307    time: 1.2500  last_time: 0.4610  data_time: 0.0533  last_data_time: 0.0451   lr: 0.00025  max_mem: 3104M
# [05/06 16:17:00 d2.utils.events]:  eta: 0:25:41  iter: 1799  total_loss: 0.9881  loss_cls: 0.526  loss_box_reg: 0.4926    time: 1.2420  last_time: 0.5992  data_time: 0.0508  last_data_time: 0.0502   lr: 0.00025  max_mem: 3104M
# [05/06 16:17:10 d2.utils.events]:  eta: 0:12:29  iter: 1819  total_loss: 0.9197  loss_cls: 0.5131  loss_box_reg: 0.4266    time: 1.2340  last_time: 0.4916  data_time: 0.0469  last_data_time: 0.0606   lr: 0.00025  max_mem: 3104M
# [05/06 16:17:21 d2.utils.events]:  eta: 0:12:06  iter: 1839  total_loss: 0.9616  loss_cls: 0.5043  loss_box_reg: 0.4746    time: 1.2263  last_time: 0.6024  data_time: 0.0474  last_data_time: 0.0474   lr: 0.00025  max_mem: 3104M
# [05/06 16:17:32 d2.utils.events]:  eta: 0:11:37  iter: 1859  total_loss: 1.02  loss_cls: 0.5477  loss_box_reg: 0.4644    time: 1.2191  last_time: 0.6076  data_time: 0.0560  last_data_time: 0.0602   lr: 0.00025  max_mem: 3104M
# [05/06 16:17:42 d2.utils.events]:  eta: 0:11:20  iter: 1879  total_loss: 0.8153  loss_cls: 0.4305  loss_box_reg: 0.3767    time: 1.2117  last_time: 0.4017  data_time: 0.0519  last_data_time: 0.0601   lr: 0.00025  max_mem: 3104M
# [05/06 16:17:53 d2.utils.events]:  eta: 0:11:04  iter: 1899  total_loss: 1.211  loss_cls: 0.6202  loss_box_reg: 0.5891    time: 1.2046  last_time: 0.6037  data_time: 0.0547  last_data_time: 0.0499   lr: 0.00025  max_mem: 3104M
# [05/06 16:18:04 d2.utils.events]:  eta: 0:10:50  iter: 1919  total_loss: 1.014  loss_cls: 0.5304  loss_box_reg: 0.4342    time: 1.1975  last_time: 0.6530  data_time: 0.0522  last_data_time: 0.1010   lr: 0.00025  max_mem: 3104M
# [05/06 16:18:14 d2.utils.events]:  eta: 0:10:36  iter: 1939  total_loss: 0.8978  loss_cls: 0.4592  loss_box_reg: 0.3759    time: 1.1907  last_time: 0.5004  data_time: 0.0478  last_data_time: 0.0474   lr: 0.00025  max_mem: 3104M
# [05/06 16:18:25 d2.utils.events]:  eta: 0:10:21  iter: 1959  total_loss: 0.9327  loss_cls: 0.5093  loss_box_reg: 0.4723    time: 1.1838  last_time: 0.4993  data_time: 0.0560  last_data_time: 0.0460   lr: 0.00025  max_mem: 3104M
# [05/06 16:18:36 d2.utils.events]:  eta: 0:10:08  iter: 1979  total_loss: 1.022  loss_cls: 0.5345  loss_box_reg: 0.4446    time: 1.1773  last_time: 0.5152  data_time: 0.0539  last_data_time: 0.0454   lr: 0.00025  max_mem: 3104M
# [05/06 16:18:47 d2.utils.events]:  eta: 0:09:54  iter: 1999  total_loss: 1.006  loss_cls: 0.4898  loss_box_reg: 0.4958    time: 1.1710  last_time: 0.6005  data_time: 0.0559  last_data_time: 0.0512   lr: 0.00025  max_mem: 3104M
# [05/06 16:18:57 d2.utils.events]:  eta: 0:09:40  iter: 2019  total_loss: 0.8637  loss_cls: 0.4524  loss_box_reg: 0.4265    time: 1.1647  last_time: 0.5456  data_time: 0.0545  last_data_time: 0.0747   lr: 0.00025  max_mem: 3104M
# [05/06 16:19:08 d2.utils.events]:  eta: 0:09:25  iter: 2039  total_loss: 0.8882  loss_cls: 0.4608  loss_box_reg: 0.4274    time: 1.1584  last_time: 0.4913  data_time: 0.0456  last_data_time: 0.0395   lr: 0.00025  max_mem: 3104M
# [05/06 16:19:19 d2.utils.events]:  eta: 0:08:36  iter: 2059  total_loss: 0.8714  loss_cls: 0.4763  loss_box_reg: 0.4109    time: 1.1525  last_time: 0.5023  data_time: 0.0540  last_data_time: 0.0448   lr: 0.00025  max_mem: 3104M
# [05/06 16:19:29 d2.utils.events]:  eta: 0:08:21  iter: 2079  total_loss: 0.7753  loss_cls: 0.4235  loss_box_reg: 0.3789    time: 1.1463  last_time: 0.3725  data_time: 0.0497  last_data_time: 0.0305   lr: 0.00025  max_mem: 3104M
# [05/06 16:19:40 d2.utils.events]:  eta: 0:08:04  iter: 2099  total_loss: 0.8265  loss_cls: 0.4127  loss_box_reg: 0.4477    time: 1.1406  last_time: 0.5099  data_time: 0.0528  last_data_time: 0.0403   lr: 0.00025  max_mem: 3104M
# [05/06 16:19:51 d2.utils.events]:  eta: 0:07:50  iter: 2119  total_loss: 0.9454  loss_cls: 0.4463  loss_box_reg: 0.4643    time: 1.1350  last_time: 0.5425  data_time: 0.0568  last_data_time: 0.0759   lr: 0.00025  max_mem: 3104M
# [05/06 16:20:01 d2.utils.events]:  eta: 0:07:36  iter: 2139  total_loss: 0.9411  loss_cls: 0.412  loss_box_reg: 0.4261    time: 1.1292  last_time: 0.5256  data_time: 0.0451  last_data_time: 0.0741   lr: 0.00025  max_mem: 3104M
# [05/06 16:20:12 d2.utils.events]:  eta: 0:07:22  iter: 2159  total_loss: 0.847  loss_cls: 0.4387  loss_box_reg: 0.441    time: 1.1236  last_time: 0.5040  data_time: 0.0540  last_data_time: 0.0544   lr: 0.00025  max_mem: 3104M
# [05/06 16:20:22 d2.utils.events]:  eta: 0:07:10  iter: 2179  total_loss: 0.9234  loss_cls: 0.4631  loss_box_reg: 0.4173    time: 1.1181  last_time: 0.5162  data_time: 0.0521  last_data_time: 0.0477   lr: 0.00025  max_mem: 3104M
# [05/06 16:20:33 d2.utils.events]:  eta: 0:06:58  iter: 2199  total_loss: 0.8183  loss_cls: 0.4243  loss_box_reg: 0.4195    time: 1.1128  last_time: 0.5998  data_time: 0.0521  last_data_time: 0.0456   lr: 0.00025  max_mem: 3104M
# [05/06 16:20:44 d2.utils.events]:  eta: 0:06:47  iter: 2219  total_loss: 0.787  loss_cls: 0.4106  loss_box_reg: 0.4122    time: 1.1075  last_time: 0.5168  data_time: 0.0539  last_data_time: 0.0442   lr: 0.00025  max_mem: 3104M
# [05/06 16:20:54 d2.utils.events]:  eta: 0:06:36  iter: 2239  total_loss: 0.9122  loss_cls: 0.4723  loss_box_reg: 0.4428    time: 1.1023  last_time: 0.5474  data_time: 0.0485  last_data_time: 0.0772   lr: 0.00025  max_mem: 3104M
# [05/06 16:21:04 d2.utils.events]:  eta: 0:06:25  iter: 2259  total_loss: 0.8491  loss_cls: 0.4717  loss_box_reg: 0.393    time: 1.0971  last_time: 0.4959  data_time: 0.0479  last_data_time: 0.0438   lr: 0.00025  max_mem: 3104M
# [05/06 16:21:15 d2.utils.events]:  eta: 0:06:14  iter: 2279  total_loss: 1.025  loss_cls: 0.548  loss_box_reg: 0.5141    time: 1.0922  last_time: 0.5938  data_time: 0.0515  last_data_time: 0.0424   lr: 0.00025  max_mem: 3104M
# [05/06 16:21:26 d2.utils.events]:  eta: 0:06:03  iter: 2299  total_loss: 0.7364  loss_cls: 0.4133  loss_box_reg: 0.3727    time: 1.0873  last_time: 0.5949  data_time: 0.0533  last_data_time: 0.0478   lr: 0.00025  max_mem: 3104M
# [05/06 16:21:36 d2.utils.events]:  eta: 0:05:52  iter: 2319  total_loss: 0.7535  loss_cls: 0.3476  loss_box_reg: 0.3979    time: 1.0825  last_time: 0.5460  data_time: 0.0544  last_data_time: 0.0931   lr: 0.00025  max_mem: 3104M
# [05/06 16:21:47 d2.utils.events]:  eta: 0:05:42  iter: 2339  total_loss: 0.9228  loss_cls: 0.4666  loss_box_reg: 0.4783    time: 1.0779  last_time: 0.5346  data_time: 0.0594  last_data_time: 0.0587   lr: 0.00025  max_mem: 3104M
# [05/06 16:21:58 d2.utils.events]:  eta: 0:05:31  iter: 2359  total_loss: 0.738  loss_cls: 0.346  loss_box_reg: 0.3526    time: 1.0731  last_time: 0.4908  data_time: 0.0467  last_data_time: 0.0375   lr: 0.00025  max_mem: 3104M
# [05/06 16:22:07 d2.utils.events]:  eta: 0:05:21  iter: 2379  total_loss: 0.8871  loss_cls: 0.4572  loss_box_reg: 0.4495    time: 1.0682  last_time: 0.5095  data_time: 0.0492  last_data_time: 0.0389   lr: 0.00025  max_mem: 3104M
# [05/06 16:22:18 d2.utils.events]:  eta: 0:05:10  iter: 2399  total_loss: 0.7386  loss_cls: 0.3692  loss_box_reg: 0.3679    time: 1.0638  last_time: 0.5129  data_time: 0.0529  last_data_time: 0.0455   lr: 0.00025  max_mem: 3104M
# [05/06 16:22:29 d2.utils.events]:  eta: 0:05:00  iter: 2419  total_loss: 0.966  loss_cls: 0.4685  loss_box_reg: 0.4626    time: 1.0596  last_time: 0.5940  data_time: 0.0516  last_data_time: 0.0385   lr: 0.00025  max_mem: 3104M
# [05/06 16:22:40 d2.utils.events]:  eta: 0:04:50  iter: 2439  total_loss: 0.7372  loss_cls: 0.3768  loss_box_reg: 0.3901    time: 1.0552  last_time: 0.6258  data_time: 0.0534  last_data_time: 0.0781   lr: 0.00025  max_mem: 3104M
# [05/06 16:22:50 d2.utils.events]:  eta: 0:04:39  iter: 2459  total_loss: 0.6304  loss_cls: 0.3293  loss_box_reg: 0.335    time: 1.0509  last_time: 0.5261  data_time: 0.0491  last_data_time: 0.0798   lr: 0.00025  max_mem: 3104M
# [05/06 16:23:01 d2.utils.events]:  eta: 0:04:29  iter: 2479  total_loss: 0.8716  loss_cls: 0.4396  loss_box_reg: 0.4153    time: 1.0467  last_time: 0.5975  data_time: 0.0489  last_data_time: 0.0473   lr: 0.00025  max_mem: 3104M
# [05/06 16:23:11 d2.utils.events]:  eta: 0:04:18  iter: 2499  total_loss: 0.7627  loss_cls: 0.3716  loss_box_reg: 0.3817    time: 1.0425  last_time: 0.5007  data_time: 0.0505  last_data_time: 0.0459   lr: 0.00025  max_mem: 3104M
# [05/06 16:23:22 d2.utils.events]:  eta: 0:04:08  iter: 2519  total_loss: 0.832  loss_cls: 0.405  loss_box_reg: 0.441    time: 1.0385  last_time: 0.5219  data_time: 0.0531  last_data_time: 0.0515   lr: 0.00025  max_mem: 3104M
# [05/06 16:23:33 d2.utils.events]:  eta: 0:03:58  iter: 2539  total_loss: 0.8871  loss_cls: 0.4581  loss_box_reg: 0.4029    time: 1.0344  last_time: 0.4408  data_time: 0.0518  last_data_time: 0.0439   lr: 0.00025  max_mem: 3104M
# [05/06 16:23:43 d2.utils.events]:  eta: 0:03:47  iter: 2559  total_loss: 0.7662  loss_cls: 0.3947  loss_box_reg: 0.4234    time: 1.0303  last_time: 0.4876  data_time: 0.0494  last_data_time: 0.0667   lr: 0.00025  max_mem: 3104M
# [05/06 16:23:53 d2.utils.events]:  eta: 0:03:37  iter: 2579  total_loss: 0.7817  loss_cls: 0.3874  loss_box_reg: 0.3819    time: 1.0264  last_time: 0.4650  data_time: 0.0474  last_data_time: 0.0462   lr: 0.00025  max_mem: 3104M
# [05/06 16:24:04 d2.utils.events]:  eta: 0:03:26  iter: 2599  total_loss: 0.7501  loss_cls: 0.368  loss_box_reg: 0.3783    time: 1.0225  last_time: 0.5103  data_time: 0.0502  last_data_time: 0.0437   lr: 0.00025  max_mem: 3104M
# [05/06 16:24:14 d2.utils.events]:  eta: 0:03:16  iter: 2619  total_loss: 0.8011  loss_cls: 0.4051  loss_box_reg: 0.3924    time: 1.0187  last_time: 0.4288  data_time: 0.0509  last_data_time: 0.0373   lr: 0.00025  max_mem: 3104M
# [05/06 16:24:25 d2.utils.events]:  eta: 0:03:06  iter: 2639  total_loss: 0.7953  loss_cls: 0.3826  loss_box_reg: 0.4575    time: 1.0150  last_time: 0.4313  data_time: 0.0527  last_data_time: 0.0370   lr: 0.00025  max_mem: 3104M
# [05/06 16:24:35 d2.utils.events]:  eta: 0:02:56  iter: 2659  total_loss: 0.604  loss_cls: 0.289  loss_box_reg: 0.3321    time: 1.0113  last_time: 0.5241  data_time: 0.0513  last_data_time: 0.0713   lr: 0.00025  max_mem: 3104M
# [05/06 16:24:46 d2.utils.events]:  eta: 0:02:45  iter: 2679  total_loss: 0.7642  loss_cls: 0.3907  loss_box_reg: 0.3747    time: 1.0077  last_time: 0.6062  data_time: 0.0471  last_data_time: 0.0508   lr: 0.00025  max_mem: 3104M
# [05/06 16:24:57 d2.utils.events]:  eta: 0:02:35  iter: 2699  total_loss: 0.6771  loss_cls: 0.3258  loss_box_reg: 0.342    time: 1.0043  last_time: 0.6026  data_time: 0.0553  last_data_time: 0.0506   lr: 0.00025  max_mem: 3104M
# [05/06 16:25:08 d2.utils.events]:  eta: 0:02:24  iter: 2719  total_loss: 0.8915  loss_cls: 0.4838  loss_box_reg: 0.4228    time: 1.0009  last_time: 0.5940  data_time: 0.0528  last_data_time: 0.0455   lr: 0.00025  max_mem: 3104M
# [05/06 16:25:18 d2.utils.events]:  eta: 0:02:14  iter: 2739  total_loss: 0.7714  loss_cls: 0.446  loss_box_reg: 0.3338    time: 0.9974  last_time: 0.5119  data_time: 0.0522  last_data_time: 0.0460   lr: 0.00025  max_mem: 3104M
# [05/06 16:25:29 d2.utils.events]:  eta: 0:02:04  iter: 2759  total_loss: 0.7988  loss_cls: 0.4194  loss_box_reg: 0.3783    time: 0.9941  last_time: 0.5947  data_time: 0.0566  last_data_time: 0.0472   lr: 0.00025  max_mem: 3104M
# [05/06 16:25:40 d2.utils.events]:  eta: 0:01:53  iter: 2779  total_loss: 0.7453  loss_cls: 0.3496  loss_box_reg: 0.3771    time: 0.9908  last_time: 0.6249  data_time: 0.0498  last_data_time: 0.0749   lr: 0.00025  max_mem: 3104M
# [05/06 16:25:51 d2.utils.events]:  eta: 0:01:43  iter: 2799  total_loss: 0.7019  loss_cls: 0.3415  loss_box_reg: 0.3699    time: 0.9877  last_time: 0.5184  data_time: 0.0478  last_data_time: 0.0480   lr: 0.00025  max_mem: 3104M
# [05/06 16:26:01 d2.utils.events]:  eta: 0:01:33  iter: 2819  total_loss: 0.7724  loss_cls: 0.439  loss_box_reg: 0.3943    time: 0.9843  last_time: 0.6017  data_time: 0.0512  last_data_time: 0.0479   lr: 0.00025  max_mem: 3104M
# [05/06 16:26:12 d2.utils.events]:  eta: 0:01:22  iter: 2839  total_loss: 0.668  loss_cls: 0.3204  loss_box_reg: 0.3554    time: 0.9810  last_time: 0.5036  data_time: 0.0551  last_data_time: 0.0527   lr: 0.00025  max_mem: 3104M
# [05/06 16:26:22 d2.utils.events]:  eta: 0:01:12  iter: 2859  total_loss: 0.6923  loss_cls: 0.3481  loss_box_reg: 0.3708    time: 0.9779  last_time: 0.4916  data_time: 0.0522  last_data_time: 0.0434   lr: 0.00025  max_mem: 3104M
# [05/06 16:26:33 d2.utils.events]:  eta: 0:01:02  iter: 2879  total_loss: 0.8285  loss_cls: 0.4299  loss_box_reg: 0.401    time: 0.9748  last_time: 0.6023  data_time: 0.0532  last_data_time: 0.0525   lr: 0.00025  max_mem: 3104M
# [05/06 16:26:44 d2.utils.events]:  eta: 0:00:51  iter: 2899  total_loss: 0.6714  loss_cls: 0.3096  loss_box_reg: 0.3886    time: 0.9718  last_time: 0.5216  data_time: 0.0492  last_data_time: 0.0701   lr: 0.00025  max_mem: 3104M
# [05/06 16:26:55 d2.utils.events]:  eta: 0:00:41  iter: 2919  total_loss: 0.7357  loss_cls: 0.3243  loss_box_reg: 0.4112    time: 0.9689  last_time: 0.4410  data_time: 0.0493  last_data_time: 0.0378   lr: 0.00025  max_mem: 3104M
# [05/06 16:27:06 d2.utils.events]:  eta: 0:00:31  iter: 2939  total_loss: 0.7379  loss_cls: 0.3091  loss_box_reg: 0.4347    time: 0.9661  last_time: 0.5197  data_time: 0.0543  last_data_time: 0.0464   lr: 0.00025  max_mem: 3104M
# [05/06 16:27:17 d2.utils.events]:  eta: 0:00:20  iter: 2959  total_loss: 0.7172  loss_cls: 0.3316  loss_box_reg: 0.3621    time: 0.9632  last_time: 0.4996  data_time: 0.0507  last_data_time: 0.0393   lr: 0.00025  max_mem: 3104M
# [05/06 16:27:27 d2.utils.events]:  eta: 0:00:10  iter: 2979  total_loss: 0.6642  loss_cls: 0.3089  loss_box_reg: 0.3416    time: 0.9603  last_time: 0.5110  data_time: 0.0526  last_data_time: 0.0462   lr: 0.00025  max_mem: 3104M
# [05/06 16:27:39 d2.utils.events]:  eta: 0:00:00  iter: 2999  total_loss: 0.6389  loss_cls: 0.3285  loss_box_reg: 0.333    time: 0.9575  last_time: 0.5984  data_time: 0.0530  last_data_time: 0.0486   lr: 0.00025  max_mem: 3104M
# [05/06 16:27:40 d2.engine.hooks]: Overall training speed: 2998 iterations in 0:47:50 (0.9575 s / it)
# [05/06 16:27:40 d2.engine.hooks]: Total training time: 0:48:00 (0:00:09 on hooks)

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5   # set the testing threshold for this model
cfg.DATASETS.TEST = ("Car_defect", )
predictor = DefaultPredictor(cfg)
# Out:
# [05/06 16:27:56 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_final.pth ...

# %%
from detectron2.utils.visualizer import ColorMode

for d in random.sample(dataset_dicts, 2):
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=Car_defect_metadata,
                   scale=0.8,
                   instance_mode=ColorMode.IMAGE_BW   # remove the colors of unsegmented pixels
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    cv2_imshow(v.get_image()[6:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=512x506>
# <PIL.Image.Image image mode=RGB size=512x506>
